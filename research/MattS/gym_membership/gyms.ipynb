# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
gym_membership_pd = pd.read_csv('output/gym_membership_by_year.csv')
digital_revenue_pd = pd.read_csv('output/physical_vs_digital_revenue.csv')

gym_revenue_pd = pd.merge(gym_membership_pd, digital_revenue_pd, left_on='year', right_on='Year')

gym_revenue_pd
# Out:
#     Unnamed: 0  year  membership_count  Year  Total Physical Revenue  \
# 0            4  2004              41.3  2004            12154.700000
# 1            5  2005              41.3  2005            11195.000000
# 2            6  2006              42.7  2006             9868.600000
# 3            7  2007              46.7  2007             7985.700000
# 4            8  2008              45.6  2008             5766.900000
# 5            9  2009              45.3  2009             4601.800000
# 6           10  2010              50.2  2010             3663.700000
# 7           11  2011              51.4  2011             3381.000000
# 8           12  2012              50.2  2012             2772.445168
# 9           13  2013              52.9  2013             2464.342964
# 10          14  2014              54.1  2014             2121.820028
# 11          15  2015              55.3  2015             1862.216951
# 12          16  2016              57.3  2016             1552.304721
# 13          17  2017              60.9  2017             1477.343897
# 14          18  2018              62.5  2018             1150.377812
# 15          19  2019              64.2  2019             1144.560844
#
#     Total Digital Revenue  Apple Revenue  % Radio Listeners
# 0              190.400000            0.0                  0
# 1             1094.900000            0.0                  0
# 2             1890.900000        19100.0                  0
# 3             2665.200000        24400.0                  0
# 4             3009.900000        37400.0                  0
# 5             3229.200000        42700.0                 92
# 6             3350.100000        65000.0                 92
# 7             3754.600000       108000.0                 93
# 8             4243.297822       156300.0                 92
# 9             4570.761537       170800.0                 92
# 10            4572.879392       182600.0                 91
# 11            4848.601897       233600.0                 91
# 12            5939.357617       215400.0                 91
# 13            7025.892161       229200.0                 90
# 14            8587.818985       265500.0                 89
# 15            9986.056279       260100.0                 89

# %%
gym_membership_pd.plot(kind="bar", x="year", y="membership_count", legend=False)
plt.xlabel("Year")
plt.ylabel("US Gym Memberships (in millions)")

plt.savefig("output/gym_memberships_by_year.png", bbox_inches="tight")
plt.show()

# %%
gym_revenue_pd.plot(kind="scatter", x="membership_count", y="Total Digital Revenue")
plt.xlabel("U.S. Gym Memberships (in millions)")
plt.ylabel("Digital Music Revenue (in millions)")
plt.title('Gym Membership vs. Digital Music Sales')

(slope, intercept, rvalue, pvalue, stderr) = linregress(gym_revenue_pd['membership_count'], gym_revenue_pd['Total Digital Revenue'])
regress_values = gym_revenue_pd['membership_count'] * slope + intercept
plt.plot(gym_revenue_pd['membership_count'], regress_values, "r-")

plt.savefig("output/membership_sales_scatter.png")
plt.show()

print(rvalue**2)
# Out:
# 0.9356021222480747
