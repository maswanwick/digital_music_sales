# %%
cd ..
# Out:
# C:\Users\brian\projects\GroupProject\digital_music_sales

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
music_data = pd.read_csv("research/Revenue_Chart_Full_Data_data.csv")
music_data
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 0                 1985                           NaN
# 1                 1986                           NaN
# 2                 1987                           NaN
# 3                 1988                           NaN
# 4                 1989                           NaN
# ..                 ...                           ...
# 434               2018                           NaN
# 435               2019                           NaN
# 436               2020                           NaN
# 437               2021                           NaN
# 438               2022                           NaN
#
#      Adjusted for Inflation Title        Format Metric  Year  \
# 0                             NaN            CD  Value  1985
# 1                             NaN            CD  Value  1986
# 2                             NaN            CD  Value  1987
# 3                             NaN            CD  Value  1988
# ...

# %%
df_1985 = music_data.loc[music_data["Year of Year Date"].isin(["1985"])]
df_1991 = music_data.loc[music_data["Year of Year Date"].isin(["1991"])]
df_1999 = music_data.loc[music_data["Year of Year Date"].isin(["1999"])]
df_2005 = music_data.loc[music_data["Year of Year Date"].isin(["2005"])]
df_2014 = music_data.loc[music_data["Year of Year Date"].isin(["2014"])]
df_2022 = music_data.loc[music_data["Year of Year Date"].isin(["2022"])]

# %%
df_1985
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 0                 1985                           NaN
# 72                1985                           NaN
# 206               1985                           NaN
# 401               1985                           NaN
#
#      Adjusted for Inflation Title        Format Metric  Year  \
# 0                             NaN            CD  Value  1985
# 72                            NaN      Cassette  Value  1985
# 206                           NaN         LP/EP  Value  1985
# 401                           NaN  Vinyl Single  Value  1985
#
#      Value (For Charting)  Adjusted for Inflation Flag  Year Date  \
# 0                   389.5                          NaN       1985
# 72                 2411.5                          NaN       1985
# 206                1280.5                          NaN       1985
# 401                 281.0                          NaN       1985
#
# ...

# %%
d_1985 = {"chart_labels": ["CD", "Cassette", "LP/EP"]}

# %%
labels = ["CD", "Cassette", "LP/EP",]

sizes = [389.5, 2411.5, 1561.5]

colors = ["olive", "darkolivegreen", "darkkhaki"]

explode = (.1, 0, 0)

# %%
plt.pie(sizes,labels=d_1985["chart_labels"],startangle=110,explode=explode,colors=colors,shadow=False, autopct="%1.2f%%")
plt.axis("square")
plt.savefig("analysis/graph_output/1985_piegraph.png", bbox_inches="tight")

# %%
df_1991
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 6                 1991                           NaN
# 40                1991                           NaN
# 78                1991                           NaN
# 101               1991                           NaN
# 212               1991                           NaN
# 254               1991                           NaN
# 407               1991                           NaN
#
#      Adjusted for Inflation Title                  Format Metric  Year  \
# 6                             NaN                      CD  Value  1991
# 40                            NaN               CD Single  Value  1991
# 78                            NaN                Cassette  Value  1991
# 101                           NaN         Cassette Single  Value  1991
# 212                           NaN                   LP/EP  Value  1991
# 254                           NaN  Music Video (Physical)  Value  1991
# ...

# %%
d_1991 = {"chart_labels": ["CD", "Cassette", "LP/EP", "Music Video (Physical)"]}

# %%
labels = ["CD", "Cassette", "LP/EP", "Music Video (Physical)"]

sizes = [4367.1, 3250, 99, 118.1]

colors = ["olive", "darkolivegreen", "darkkhaki", "olivedrab"]

explode = (0, .05, .2, .1)

# %%
plt.pie(sizes,labels=d_1991["chart_labels"],startangle=135,explode=explode,colors=colors,shadow=False, autopct="%1.2f%%")
plt.axis("square")
plt.savefig("analysis/graph_output/1991_piegraph.png", bbox_inches="tight")

# %%
df_2014
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 29                2014                           NaN
# 63                2014                           NaN
# 123               2014                           NaN
# 142               2014                           NaN
# 160               2014                           NaN
# 179               2014                           NaN
# 197               2014                           NaN
# 235               2014                           NaN
# 277               2014                           NaN
# 289               2014                           NaN
# 321               2014                           NaN
# 339               2014                           NaN
# 359               2014                           NaN
# 378               2014                           NaN
# 392               2014                           NaN
# 430               2014                           NaN
#
# ...

# %%
d_2014 = {"chart_labels": ["CD", "LP/EP", "Music Video (Physical)", "Digital Download", "Streaming with Ads", 
                           "Paid Streaming", "Music Licences"]}

# %%
labels = ["CD", "LP/EP", "Music Video (Physical)", "Digital Download", "Streaming with Ads", "Paid Streaming",
          "Music Licences"]

sizes = [1782, 249.3, 89.7, 2553.1, 283.8, 770.3, 963.1]

colors = ["olive", "darkkhaki", "olivedrab", "darkred", "brown", "lightcoral", "lightpink"]

explode = (0, .2, 0, 0, 0, 0, 0)

# %%
plt.pie(sizes,labels=d_2014["chart_labels"],startangle=35,explode=explode,colors=colors,shadow=False, autopct="%1.2f%%")
plt.axis("square")
plt.savefig("analysis/graph_output/2014_piegraph.png", bbox_inches="tight")

# %%
df_2022
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 37                2022                           NaN
# 71                2022                           NaN
# 131               2022                           NaN
# 150               2022                           NaN
# 168               2022                           NaN
# 187               2022                           NaN
# 205               2022                           NaN
# 243               2022                           NaN
# 251               2022                           NaN
# 285               2022                           NaN
# 297               2022                           NaN
# 304               2022                           NaN
# 311               2022                           NaN
# 329               2022                           NaN
# 347               2022                           NaN
# 367               2022                           NaN
# 386               2022                           NaN
# ...

# %%
d_2022 = {"chart_labels": ["CD", "LP/EP", "Digital Download", "Streaming with Ads", 
                           "Paid Streaming", "Music Licences"]}

# %%
labels = ["CD", "LP/EP", "Digital Download", "Streaming with Ads", "Paid Streaming",
          "Music Licences"]

sizes = [489.5, 1130, 468.4, 2064.3, 10242, 959.6]

colors = ["olive", "darkkhaki", "darkred", "brown", "lightcoral", "lightpink",]

explode = (0, .2, 0, 0, 0, 0)

# %%
plt.pie(sizes,labels=d_2022["chart_labels"],startangle=115,explode=explode,colors=colors,shadow=False, autopct="%1.2f%%")
plt.axis("square")
plt.savefig("analysis/graph_output/2022_piegraph.png", bbox_inches="tight")

# %%
d_2022 = {"chart_labels": ["CD", "LP/EP", "Music Video (Physical)"]}

# %%
labels = ["CD", "LP/EP", "Music Video (Physical)"]

sizes = [489.5, 1130, 11.3]

colors = ["olive", "darkkhaki", "olivedrab"]

explode = (0, .1, 0)

# %%
plt.pie(sizes,labels=d_2022["chart_labels"],startangle=150,explode=explode,colors=colors,shadow=False, autopct="%1.2f%%")
plt.axis("square")
plt.savefig("analysis/graph_output/2022_piegraph_physical.png", bbox_inches="tight")

# %%
df_1999
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 14                1999                           NaN
# 48                1999                           NaN
# 86                1999                           NaN
# 109               1999                           NaN
# 220               1999                           NaN
# 262               1999                           NaN
# 415               1999                           NaN
#
#      Adjusted for Inflation Title                  Format Metric  Year  \
# 14                            NaN                      CD  Value  1999
# 48                            NaN               CD Single  Value  1999
# 86                            NaN                Cassette  Value  1999
# 109                           NaN         Cassette Single  Value  1999
# 220                           NaN                   LP/EP  Value  1999
# 262                           NaN  Music Video (Physical)  Value  1999
# ...

# %%
d_1999 = {"chart_labels": ["CD", "LP/EP", "Music Video (Physical)", "Cassette"]}

# %%
labels = ["CD", "LP/EP", "Music Video (Physical)", "Cassette"]

sizes = [13038.7, 59.7, 376.7, 1109.6]

colors = ["olive", "darkkhaki", "olivedrab", "darkolivegreen"]

explode = (.1, 0, 0, 0)

# %%
plt.pie(sizes,labels=d_1999["chart_labels"],startangle=55,explode=explode,colors=colors,shadow=False, autopct="%1.2f%%")
plt.axis("square")
plt.savefig("analysis/graph_output/1999_piegraph.png", bbox_inches="tight")

# %%
df_2005
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 20                2005                           NaN
# 54                2005                           NaN
# 92                2005                           NaN
# 115               2005                           NaN
# 133               2005                           NaN
# 151               2005                           NaN
# 170               2005                           NaN
# 188               2005                           NaN
# 226               2005                           NaN
# 268               2005                           NaN
# 312               2005                           NaN
# 330               2005                           NaN
# 350               2005                           NaN
# 369               2005                           NaN
# 421               2005                           NaN
#
#      Adjusted for Inflation Title                       Format Metric  Year  \
# ...

# %%
d_2005 = {"chart_labels": ["CD", "LP/EP", "Digital Download", "Paid Streaming", "Music Video (Physical)"]}

# %%
labels = ["CD", "LP/EP", "Digital Download", "Paid Streaming", "Music Video (Physical)"]

sizes = [10552.3, 27.4, 924.3, 149.2, 602.2]

colors = ["olive", "darkkhaki", "darkred", "lightcoral", "olivedrab"]

explode = (0, 0, .1, 0, 0)

# %%
plt.pie(sizes,labels=d_2005["chart_labels"],startangle=195,explode=explode,colors=colors,shadow=False, autopct="%1.2f%%")
plt.axis("square")
plt.savefig("analysis/graph_output/2005_piegraph.png", bbox_inches="tight")
